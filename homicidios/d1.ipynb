# %%
import requests

url = "https://homicidios.spd.gov.cl/homicidios/estadisticasPoliciales-ajax.php"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:137.0) Gecko/20100101 Firefox/137.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "es-CL,es;q=0.8,en-US;q=0.5,en;q=0.3",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Priority": "u=0",
    "Referer": "https://homicidios.spd.gov.cl/homicidios/estadisticasPoliciales.php"
}
data = {
    "token": "202d8f3ba54058c848b7d7a6dbcf60bf",
    "numPagina": "1",
    "regPagina": "16",
    "atr01": "2025",
    "atr02": "Enero",
    "atr03": ""
}

response = requests.post(url, headers=headers, data=data)
print(response.text)
# Out:
# 	<div class="col-xs-offset-0 col-xs-12 col-sm-offset-2 col-sm-8">
# 		<div align="center">
# 			<div class="col-xs-12 col-sm-6" align="left">
# 				<label class="label_paginador">Registros: 16</label>
# 			</div>
# 			<div class="col-xs-12 col-sm-6" align="right">
# 				<label class="label_paginador">            <table>
#                 <tr>
#                 	<td class="label_paginador">&nbsp;Mostrar:&nbsp;</td>
#                     <td>
#                         <select id='cmb_paginacion_cantidad' name='cmb_paginacion_cantidad' class="form-control label_paginador"
#                         	style='width:80px; height: 25px; padding-top: 3px; padding-left: 1px;'
#                             onchange='cargarRegistros(1, this.value)'>
# 							                                    <option value='16' selected>16</option>
# 							                          		<option value='16' selected>Todos</option>
#                         </select>
#                     </td>
# 					              	</tr>
# 			</table>
# 		</label>
# 			</div>
# 		</div>
# 		<!-- ---------------------------------------------------------------- -->
# 		<div class="col-xs-12 table-responsive">
# 			<table class="table table-sm table-hover" >
# 				<thead>
# 					<th style="text-align:center" width="15%">Año</th>
# 					<th style="text-align:center" width="15%">Mes</th>
# 					<th style="text-align:center" width="40%">Regi&oacute;n</th>
# 					<th style="text-align:center" width="15%">Frecuencia 2024</th>
# 					<th style="text-align:center" width="15%">Frecuencia 2025</th>
# 					<!-- <th style="text-align:center" width="30%">Tasa de homicidios</th>
# 					<th style="text-align:center" width="10%">Varianza de homicidios</th>-->
# 				</thead>
#
# 				<tbody>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Arica y Parinacota </td>
# 							<td style="text-align:center" valign="top">3</td>
# 							<td style="text-align:center" valign="top">5</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Tarapacá</td>
# 							<td style="text-align:center" valign="top">3</td>
# 							<td style="text-align:center" valign="top">2</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Antofagasta</td>
# 							<td style="text-align:center" valign="top">1</td>
# 							<td style="text-align:center" valign="top">3</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Atacama</td>
# 							<td style="text-align:center" valign="top">2</td>
# 							<td style="text-align:center" valign="top">1</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Coquimbo</td>
# 							<td style="text-align:center" valign="top">1</td>
# 							<td style="text-align:center" valign="top">5</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Valparaíso</td>
# 							<td style="text-align:center" valign="top">10</td>
# 							<td style="text-align:center" valign="top">7</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región Metropolitana de Santiago</td>
# 							<td style="text-align:center" valign="top">59</td>
# 							<td style="text-align:center" valign="top">43</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región del Libertador Gral. Bernardo O’Higgins</td>
# 							<td style="text-align:center" valign="top">12</td>
# 							<td style="text-align:center" valign="top">2</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región del Maule</td>
# 							<td style="text-align:center" valign="top">4</td>
# 							<td style="text-align:center" valign="top">4</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Ñuble</td>
# 							<td style="text-align:center" valign="top">0</td>
# 							<td style="text-align:center" valign="top">0</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región del Biobío</td>
# 							<td style="text-align:center" valign="top">13</td>
# 							<td style="text-align:center" valign="top">4</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de La Araucanía</td>
# 							<td style="text-align:center" valign="top">5</td>
# 							<td style="text-align:center" valign="top">9</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Los Ríos</td>
# 							<td style="text-align:center" valign="top">3</td>
# 							<td style="text-align:center" valign="top">2</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Los Lagos</td>
# 							<td style="text-align:center" valign="top">6</td>
# 							<td style="text-align:center" valign="top">11</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Aysén del Gral. Carlos Ibáñez del Campo</td>
# 							<td style="text-align:center" valign="top">1</td>
# 							<td style="text-align:center" valign="top">0</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 										<tr class="tr_cuerpo" valign="top">
# 							<td style="text-align:center" valign="top">2025</td>
# 							<td style="text-align:justify; padding-left: 15px;" valign="top">Enero</td>
# 							<td style="text-align:left" valign="top">Región de Magallanes y de la Antártica Chilena</td>
# 							<td style="text-align:center" valign="top">0</td>
# 							<td style="text-align:center" valign="top">0</td>
# 							<!--  <td style="text-align:center" valign="top"></td>
# 							<td style="text-align:center" valign="top">0.00</td>-->
# 						</tr>
# 								</tbody>
# 			</table>
# 			<!--
# 			<div class="col-xs-12 col-sm-12" align="right">
# 				<label class="label_paginador"></label>
# 			</div> -->
# 		</div>
# 	</div>
# 	<div class="col-xs-offset-2 col-xs-10 col-sm-offset-4 col-sm-4"
# 		style="text-align: center; font-size: 14px; background-color: #1F4572; color:#FFFFFF; padding:8px; cursor: pointer;">
# 		<a onclick="abrir_enlace('exportarReportePoliciales-ajax.php?cond=SPc2fDrSVvRql%2F7Ze1HCv8ZEhSo%2F%2B1EdDyNzFxT2WzrFP6qhTwHThBj%2FFqJXnLxVofB%2Bd9ALuULzgktViMCXsLK8Y9sWcUAtC9%2BSnF2xnsFIXkov5TJ43sEUwTXG%2F6ni')"><b style="color: #FFFFFF;">Descargar Datos</b></a>
# 		<br>
# 	</div>
# 	<br />

# %%
import pandas as pd

# %%
df = pd.read_html(response.text)
df
# Out:
# C:\Users\limc_\AppData\Local\Temp\ipykernel_20312\2319362442.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(response.text)
# [          0          1
#  0  Mostrar:  16  Todos,
#       Año    Mes                                             Región  \
#  0   2025  Enero                       Región de Arica y Parinacota
#  1   2025  Enero                                 Región de Tarapacá
#  2   2025  Enero                              Región de Antofagasta
#  3   2025  Enero                                  Región de Atacama
#  4   2025  Enero                                 Región de Coquimbo
#  5   2025  Enero                               Región de Valparaíso
#  6   2025  Enero                   Región Metropolitana de Santiago
#  7   2025  Enero     Región del Libertador Gral. Bernardo O’Higgins
#  8   2025  Enero                                   Región del Maule
#  9   2025  Enero                                    Región de Ñuble
#  10  2025  Enero                                  Región del Biobío
#  11  2025  Enero                             Región de La Araucanía
#  12  2025  Enero                                 Región de Los Ríos
#  13  2025  Enero                                Región de Los Lagos
#  14  2025  Enero  Región de Aysén del Gral. Carlos Ibáñez del Campo
#  15  2025  Enero     Región de Magallanes y de la Antártica Chilena
#
#      Frecuencia 2024  Frecuencia 2025
#  0                 3                5
#  1                 3                2
#  2                 1                3
#  3                 2                1
#  4                 1                5
#  5                10                7
#  6                59               43
#  7                12                2
#  8                 4                4
#  9                 0                0
#  10               13                4
#  11                5                9
#  12                3                2
#  13                6               11
#  14                1                0
#  15                0                0  ]

# %%
df[1]
# Out:
#      Año    Mes                                             Región  \
# 0   2025  Enero                       Región de Arica y Parinacota
# 1   2025  Enero                                 Región de Tarapacá
# 2   2025  Enero                              Región de Antofagasta
# 3   2025  Enero                                  Región de Atacama
# 4   2025  Enero                                 Región de Coquimbo
# 5   2025  Enero                               Región de Valparaíso
# 6   2025  Enero                   Región Metropolitana de Santiago
# 7   2025  Enero     Región del Libertador Gral. Bernardo O’Higgins
# 8   2025  Enero                                   Región del Maule
# 9   2025  Enero                                    Región de Ñuble
# 10  2025  Enero                                  Región del Biobío
# 11  2025  Enero                             Región de La Araucanía
# 12  2025  Enero                                 Región de Los Ríos
# 13  2025  Enero                                Región de Los Lagos
# 14  2025  Enero  Región de Aysén del Gral. Carlos Ibáñez del Campo
# 15  2025  Enero     Región de Magallanes y de la Antártica Chilena
#
#     Frecuencia 2024  Frecuencia 2025
# 0                 3                5
# 1                 3                2
# 2                 1                3
# 3                 2                1
# 4                 1                5
# 5                10                7
# 6                59               43
# 7                12                2
# 8                 4                4
# 9                 0                0
# 10               13                4
# 11                5                9
# 12                3                2
# 13                6               11
# 14                1                0
# 15                0                0

# %%
import requests

url = "https://homicidios.spd.gov.cl/homicidios/estadisticasPoliciales-ajax.php"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:137.0) Gecko/20100101 Firefox/137.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "es-CL,es;q=0.8,en-US;q=0.5,en;q=0.3",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Priority": "u=0",
    "Referer": "https://homicidios.spd.gov.cl/homicidios/estadisticasPoliciales.php"
}
data = {
    "token": "202d8f3ba54058c848b7d7a6dbcf60bf",
    "numPagina": "1",
    "regPagina": "16",
    "atr01": "2025",
    "atr02": "Febrero",
    "atr03": ""
}

response = requests.post(url, headers=headers, data=data)
print(response.text)

# %%
import requests

url = "https://homicidios.spd.gov.cl/homicidios/estadisticasCead-ajax.php"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:137.0) Gecko/20100101 Firefox/137.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "es-CL,es;q=0.8,en-US;q=0.5,en;q=0.3",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Priority": "u=0",
    "Referer": "https://homicidios.spd.gov.cl/homicidios/estadisticasCead.php"
}
data = {
    "token": "ebfe6454c9acfbe42d3ac6f5c05ad5f4",
    "numPagina": "1",
    "regPagina": "16",
    "atr01": "2024",
    "atr02": "Febrero",
    "atr03": ""
}

response = requests.post(url, headers=headers, data=data)
#print(response.text)
df = pd.read_html(response.text)
df[1]
# Out:
# C:\Users\limc_\AppData\Local\Temp\ipykernel_20312\3316820696.py:27: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(response.text)
#      Año      Mes                                             Region  \
# 0   2024  Febrero                       Región de Arica y Parinacota
# 1   2024  Febrero                                 Región de Tarapacá
# 2   2024  Febrero                              Región de Antofagasta
# 3   2024  Febrero                                  Región de Atacama
# 4   2024  Febrero                                 Región de Coquimbo
# 5   2024  Febrero                               Región de Valparaíso
# 6   2024  Febrero                   Región Metropolitana de Santiago
# 7   2024  Febrero     Región del Libertador Gral. Bernardo O’Higgins
# 8   2024  Febrero                                   Región del Maule
# 9   2024  Febrero                                    Región de Ñuble
# 10  2024  Febrero                                  Región del Biobío
# 11  2024  Febrero                             Región de La Araucanía
# 12  2024  Febrero                                 Región de Los Ríos
# 13  2024  Febrero                                Región de Los Lagos
# 14  2024  Febrero  Región de Aysén del Gral. Carlos Ibáñez del Campo
# 15  2024  Febrero     Región de Magallanes y de la Antártica Chilena
#
#     Frecuencia
# 0            1
# 1            3
# 2            5
# 3            2
# 4            3
# 5            5
# 6           30
# 7            3
# 8            6
# 9            1
# 10           3
# 11           2
# 12           1
# 13           1
# 14           2
# 15           2

# %%
import requests

url = "https://homicidios.spd.gov.cl/homicidios/estadisticasMinisterio-ajax.php"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:137.0) Gecko/20100101 Firefox/137.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "es-CL,es;q=0.8,en-US;q=0.5,en;q=0.3",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Priority": "u=0",
    "Referer": "https://homicidios.spd.gov.cl/homicidios/estadisticasMinisterio.php"
}
data = {
    "token": "61689f586d3ed3c5acbd1a30c964236e",
    "numPagina": "1",
    "regPagina": "16",
    "atr01": "2024",
    "atr02": "Marzo",
    "atr03": ""
}

response = requests.post(url, headers=headers, data=data)
df = pd.read_html(response.text)
df[1]
# Out:
# C:\Users\limc_\AppData\Local\Temp\ipykernel_20312\2122531801.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(response.text)
#      Año    Mes                                             Region  Frecuencia
# 0   2024  Marzo                       Región de Arica y Parinacota           1
# 1   2024  Marzo                                 Región de Tarapacá           6
# 2   2024  Marzo                              Región de Antofagasta           8
# 3   2024  Marzo                                  Región de Atacama           6
# 4   2024  Marzo                                 Región de Coquimbo          12
# 5   2024  Marzo                               Región de Valparaíso          26
# 6   2024  Marzo                   Región Metropolitana de Santiago         136
# 7   2024  Marzo     Región del Libertador Gral. Bernardo O’Higgins          14
# 8   2024  Marzo                                   Región del Maule          14
# 9   2024  Marzo                                    Región de Ñuble          14
# 10  2024  Marzo                                  Región del Biobío          31
# 11  2024  Marzo                             Región de La Araucanía          25
# 12  2024  Marzo                                 Región de Los Ríos           7
# 13  2024  Marzo                                Región de Los Lagos          22
# 14  2024  Marzo  Región de Aysén del Gral. Carlos Ibáñez del Campo           4
# 15  2024  Marzo                         Sin información registrada           4
